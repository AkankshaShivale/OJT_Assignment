# %% [markdown]
# # <span style="color:YellowGreen">Akanksha Kisan Shivale</span>
# # <span style="color:YellowGreen">23092002  </span>
# # <span style="color:YellowGreen"> IMCA 1st</span>

# %% [markdown]
# # <span style="color:teal"><h2>Q1. Data Visualization and Statistical Measures: </h2></span>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

file_path = 'C:\\My Files\\Iris.csv'
iris_data = pd.read_csv(file_path)

# %%
iris_data.hist(edgecolor='black', linewidth=1.2, figsize=(12, 8))
plt.show()

# %%
iris_data.drop(['Id'], axis=1).boxplot(by='Species', figsize=(12, 8))
plt.tight_layout()
plt.show()

# %%
def calculate_statistics(data):
    return {
        "Mean": data.mean(),
        "Median": data.median(),
        "Mode": data.mode().iloc[0],
        "Standard Deviation": data.std(),
        "Variance": data.var(),
        "Minimum": data.min(),
        "Maximum": data.max(),
        "Range": data.max() - data.min()
    }


numerical_data = iris_data.select_dtypes(include=['float64', 'int64'])


for column in numerical_data.columns:
    stats = calculate_statistics(numerical_data[column])
    print(f"Statistics for {column}:")
    for stat_name, value in stats.items():
        print(f"{stat_name}: {value}")
    print("\n")
# Out:
# Statistics for Id:
# Mean: 75.5
# Median: 75.5
# Mode: 1
# Standard Deviation: 43.445367992456916
# Variance: 1887.5
# Minimum: 1
# Maximum: 150
# Range: 149
#
#
# Statistics for SepalLengthCm:
# Mean: 5.843333333333334
# Median: 5.8
# Mode: 5.0
# Standard Deviation: 0.8280661279778629
# Variance: 0.6856935123042505
# Minimum: 4.3
# Maximum: 7.9
# Range: 3.6000000000000005
#
#
# Statistics for SepalWidthCm:
# Mean: 3.0540000000000003
# Median: 3.0
# Mode: 3.0
# Standard Deviation: 0.4335943113621737
# Variance: 0.18800402684563763
# Minimum: 2.0
# Maximum: 4.4
# Range: 2.4000000000000004
#
#
# Statistics for PetalLengthCm:
# Mean: 3.758666666666666
# Median: 4.35
# Mode: 1.5
# Standard Deviation: 1.7644204199522617
# Variance: 3.1131794183445156
# Minimum: 1.0
# Maximum: 6.9
# Range: 5.9
#
#
# Statistics for PetalWidthCm:
# Mean: 1.1986666666666668
# Median: 1.3
# Mode: 0.2
# Standard Deviation: 0.7631607417008414
# Variance: 0.5824143176733784
# Minimum: 0.1
# Maximum: 2.5
# ...
